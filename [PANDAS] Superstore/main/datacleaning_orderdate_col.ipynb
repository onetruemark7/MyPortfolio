# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v2.csv')
df
# Out:
#        Row ID         Order ID    Order Date     Ship Date       Ship Mode  \
# 0       31518   CA-2012-169397    24-12-2012    27-12-2012     First Class
# 1        6224   US-2011-144729    21-07-2011    24-07-2011     First Class
# 2       15333  IT-2014-4749412    18-09-2014    23-09-2014  Standard Class
# 3       49259     NI-2013-4420  Apr 10, 2013    10/10/2013  Standard Class
# 4       24199    IN-2014-14423    29-10-2014    30-10-2014     First Class
# ...       ...              ...           ...           ...             ...
# 51365   17526  ES-2014-2057259      2/8/2014      5/8/2014     First Class
# 51366   36055   CA-2011-121573     3/11/2011  Jul 11, 2011  Standard Class
# 51367   43576     TU-2011-9190    23-12-2011    28-12-2011    Second Class
# 51368   22403    IN-2013-35388      7/8/2013     11/8/2013  Standard Class
# 51369   12513  ES-2011-1222857    30-09-2011    2011-04-10  Standard Class
#
#       Customer ID     Customer Name    Segment            City  \
# ...

# %%
df['Order Date'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Order Date
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed', dayfirst=True, errors='coerce')
# Out:
# 0       2012-12-24
# 1       2011-07-21
# 2       2014-09-18
# 3       2013-04-10
# 4       2014-10-29
#            ...
# 51365   2014-08-02
# 51366   2011-11-03
# 51367   2011-12-23
# 51368   2013-08-07
# 51369   2011-09-30
# Name: Order Date, Length: 51370, dtype: datetime64[us]

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed', dayfirst=True, errors='coerce')

# %%
df[df['Order Date'].isna()]
# Out:
#        Row ID         Order ID Order Date   Ship Date       Ship Mode  \
# 269     32092   CA-2014-151428        NaT  27-09-2014  Standard Class
# 802     18648  ES-2013-4986805        NaT  25-09-2013     First Class
# 1009    25777    IN-2014-22228        NaT  10/11/2014    Second Class
# 1155      956   MX-2014-102064        NaT  28-09-2014  STANDARD CLASS
# 2381    43398     GH-2012-2610        NaT  19-08-2012    Second Class
# ...       ...              ...        ...         ...             ...
# 48774   34374   CA-2011-143903        NaT  24-07-2011  Standard Class
# 48860    9785   MX-2012-166485        NaT  14-09-2012    Second Class
# 49916   13501  ES-2014-5759001        NaT  17-12-2014  standard class
# 50195   26147    IN-2011-67616        NaT  20-12-2011    Second Class
# 51044   14185  IT-2013-2494049        NaT  28-06-2013  Standard Class
#
#       Customer ID      Customer Name      Segment                 City  \
# ...

# %%
df['Order Date'] = df['Order Date'].fillna(df['Order Date'].ffill())

# %%
df['Order Date'].isna().sum()
# Out:
# np.int64(0)

# %%
df.to_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v3.csv',index=False)
