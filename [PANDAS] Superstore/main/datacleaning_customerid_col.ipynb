# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v5.csv')
df
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       31518   CA-2012-169397  2012-12-24  2012-12-27     First Class
# 1        6224   US-2011-144729  2011-07-21  2011-07-24     First Class
# 2       15333  IT-2014-4749412  2014-09-18  2014-09-23  Standard Class
# 3       49259     NI-2013-4420  2013-04-10  2013-10-10  Standard Class
# 4       24199    IN-2014-14423  2014-10-29  2014-10-30     First Class
# ...       ...              ...         ...         ...             ...
# 51365   17526  ES-2014-2057259  2014-08-02  2014-08-05     First Class
# 51366   36055   CA-2011-121573  2011-11-03  2011-07-11  Standard Class
# 51367   43576     TU-2011-9190  2011-12-23  2011-12-28    Second Class
# 51368   22403    IN-2013-35388  2013-08-07  2013-08-11  Standard Class
# 51369   12513  ES-2011-1222857  2011-09-30  2011-10-04  Standard Class
#
#       Customer ID     Customer Name    Segment            City  \
# ...

# %%
df['Customer ID'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Customer ID
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['Customer ID'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Customer ID'].str.contains(r'[^A-Za-z0-9-]', regex=True)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51365    False
# 51366    False
# 51367    False
# 51368    False
# 51369    False
# Name: Customer ID, Length: 51370, dtype: bool

# %%
df[df['Customer ID'].str.contains(r'[^A-Za-z0-9- ]', regex=True)]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Country, Postal Code, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['Customer ID'] = df['Customer ID'].str.lstrip().str.rstrip()

# %%
df['Customer ID'].value_counts()
# Out:
# Customer ID
# PO-18850    97
# BE-11335    94
# JG-15805    90
# SW-20755    89
# MY-18295    85
#             ..
# DK-2985      1
# ME-8010      1
# ZC-11910     1
# RC-9825      1
# MG-7650      1
# Name: count, Length: 1590, dtype: int64

# %%
df.to_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v6.csv',index=False)
