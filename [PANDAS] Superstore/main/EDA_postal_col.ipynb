# %%
import numpy as np
import pandas as pd

df = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_clean.csv')

df
# Out:
#        Row ID         Order ID  Order Date     Ship Date       Ship Mode  \
# 0       31518   CA-2012-169397  2012-12-24    27-12-2012     First Class
# 1        6224   US-2011-144729  2011-07-21    24-07-2011     First Class
# 2       15333  IT-2014-4749412  2014-09-18    23-09-2014  Standard Class
# 3       49259     NI-2013-4420  2013-04-10    10/10/2013  Standard Class
# 4       24199    IN-2014-14423  2014-10-29    30-10-2014     First Class
# ...       ...              ...         ...           ...             ...
# 51365   17526  ES-2014-2057259  2014-08-02      5/8/2014     First Class
# 51366   36055   CA-2011-121573  2011-11-03  Jul 11, 2011  Standard Class
# 51367   43576     TU-2011-9190  2011-12-23    28-12-2011    Second Class
# 51368   22403    IN-2013-35388  2013-08-07     11/8/2013  Standard Class
# 51369   12513  ES-2011-1222857  2011-09-30    2011-04-10  Standard Class
#
#       Customer ID     Customer Name    Segment            City  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51370 entries, 0 to 51369
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51370 non-null  int64
#  1   Order ID        51370 non-null  str
#  2   Order Date      51370 non-null  str
#  3   Ship Date       51370 non-null  str
#  4   Ship Mode       51370 non-null  str
#  5   Customer ID     51370 non-null  str
#  6   Customer Name   51336 non-null  str
#  7   Segment         51370 non-null  str
#  8   City            51351 non-null  str
#  9   State           51339 non-null  str
#  10  Country         51370 non-null  str
#  11  Postal Code     51370 non-null  int64
#  12  Market          51370 non-null  str
#  13  Region          51370 non-null  str
#  14  Product ID      51370 non-null  str
#  15  Category        51370 non-null  str
#  16  Sub-Category    51370 non-null  str
#  17  Product Name    51370 non-null  str
# ...

# %%
df.groupby(
    'Postal Code'
)[[
    'Sales',
    'Quantity',
    'Discount',
    'Profit'
]].agg(
    Total_Sales = ('Sales','sum'),
    Average_Sales = ('Sales','mean'),
    Minimum_Sales = ('Sales','min'),
    Maximum_Sales = ('Sales','max'),
	Sales_Standard_Deviation = ('Sales','std'),
    Number_of_Transaction = ('Sales','count'),

    Total_Units_Sold = ('Quantity','sum'),
    Average_Units_Sold = ('Quantity','mean'),
    Minimum_Quantity = ('Quantity','min'),
    Maximum_Quantity = ('Quantity','max'),
    Quantity_Standard_Deviation = ('Quantity','std'),

    Total_Discount = ('Discount','sum'),
    Average_Discount = ('Discount','mean'),
    Minimum_Discount = ('Discount','min'),
    Maximum_Discount = ('Discount','max'),
    Discount_Standard_Deviation = ('Discount','std'),

    Total_Profit = ('Profit','sum'),
    Average_Profit = ('Profit','mean'),
    Minimum_Profit = ('Profit','min'),
    Maximum_Profit = ('Profit','max'),
    Profit_Standard_Deviation = ('Profit','std')
).round(2)
# Out:
#              Total_Sales  Average_Sales  Minimum_Sales  Maximum_Sales  \
# Postal Code
# 0            10388486.62         250.43           1.16        7958.58
# 1040              301.96         301.96         301.96         301.96
# 1453              217.49          36.25           3.15         104.90
# 1752              206.64         103.32          14.82         191.82
# 1810              435.85         108.96          11.21         354.90
# ...                  ...            ...            ...            ...
# 98502            1020.45         204.09          14.03         603.92
# 98632             119.21          39.74          18.24          76.12
# 98661             686.84         137.37           9.64         316.00
# 99207            2597.49         324.69          23.84         837.60
# 99301            2201.11         366.85           5.88         975.92
#
#              Sales_Standard_Deviation  Number_of_Transaction  \
# Postal Code
# ...

# %%
#result: 0 means Unknown. Since its in real dataset, its impossible to have majority results of zero.
