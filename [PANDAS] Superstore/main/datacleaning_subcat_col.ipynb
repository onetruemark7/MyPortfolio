# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v3.csv')
df
# Out:
#        Row ID         Order ID  Order Date     Ship Date       Ship Mode  \
# 0       31518   CA-2012-169397  2012-12-24    27-12-2012     First Class
# 1        6224   US-2011-144729  2011-07-21    24-07-2011     First Class
# 2       15333  IT-2014-4749412  2014-09-18    23-09-2014  Standard Class
# 3       49259     NI-2013-4420  2013-04-10    10/10/2013  Standard Class
# 4       24199    IN-2014-14423  2014-10-29    30-10-2014     First Class
# ...       ...              ...         ...           ...             ...
# 51365   17526  ES-2014-2057259  2014-08-02      5/8/2014     First Class
# 51366   36055   CA-2011-121573  2011-11-03  Jul 11, 2011  Standard Class
# 51367   43576     TU-2011-9190  2011-12-23    28-12-2011    Second Class
# 51368   22403    IN-2013-35388  2013-08-07     11/8/2013  Standard Class
# 51369   12513  ES-2011-1222857  2011-09-30    2011-04-10  Standard Class
#
#       Customer ID     Customer Name    Segment            City  \
# ...

# %%
df['Sub-Category'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Sub-Category
# Non-Null Count  Dtype
# --------------  -----
# 50849 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        6059
# Storage        4853
# Art            4824
# Paper          3391
# Chairs         3290
# Phones         3199
# Furnishings    3145
# Accessories    3039
# Labels         2563
# Supplies       2398
# Envelopes      2396
# Fasteners      2389
# Bookcases      2380
# Copiers        2190
# Appliances     1731
# Machines       1463
# Tables          817
# ?                92
# Unknown          86
# Storag           72
# -                70
# Storrage         67
# Phone            62
# Papper           53
# papers           52
# Phonez           48
# chair            46
# Chiars           42
# Tabels           17
# Table            15
# Name: count, dtype: int64

# %%
for x in df['Sub-Category'].drop_duplicates():
    print(x)
# Out:
# Binders
# Fasteners
# Art
# Furnishings
# Chairs
# Accessories
# Machines
# Paper
# Envelopes
# Unknown
# Supplies
# Labels
# Copiers
# Storage
# Bookcases
# Appliances
# Phones
# Tables

# %%
df['Sub-Category'] = df['Sub-Category'].replace(
    {
        '?':'Unknown',
        '-':'Unknown',
    }
)

# %%
df['Sub-Category'].isna().sum()
# Out:
# np.int64(521)

# %%
df['Sub-Category'] = df['Sub-Category'].fillna('Unknown')

# %%
df['Sub-Category'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Sub-Category
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df.to_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v14.csv',index=False)
