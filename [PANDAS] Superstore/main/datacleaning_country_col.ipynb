# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v10.csv')
df
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       31518   CA-2012-169397  2012-12-24  2012-12-27     First Class
# 1        6224   US-2011-144729  2011-07-21  2011-07-24     First Class
# 2       15333  IT-2014-4749412  2014-09-18  2014-09-23  Standard Class
# 3       49259     NI-2013-4420  2013-04-10  2013-10-10  Standard Class
# 4       24199    IN-2014-14423  2014-10-29  2014-10-30     First Class
# ...       ...              ...         ...         ...             ...
# 51365   17526  ES-2014-2057259  2014-08-02  2014-08-05     First Class
# 51366   36055   CA-2011-121573  2011-11-03  2011-07-11  Standard Class
# 51367   43576     TU-2011-9190  2011-12-23  2011-12-28    Second Class
# 51368   22403    IN-2013-35388  2013-08-07  2013-08-11  Standard Class
# 51369   12513  ES-2011-1222857  2011-09-30  2011-10-04  Standard Class
#
#       Customer ID     Customer Name    Segment            City  \
# ...

# %%
df['Country'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Country
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['Country'].drop_duplicates()
# Out:
# 0            United States
# 1                   Panama
# 2           United Kingdom
# 3                  Nigeria
# 4                Indonesia
#                ...
# 20897              Armenia
# 21023    Equatorial Guinea
# 23149           Mauritania
# 29453          South Sudan
# 43320             Slovenia
# Name: Country, Length: 154, dtype: str

# %%
df['Country'] = df['Country'].str.lstrip().str.rstrip().str.title()

# %%
df['Country'].value_counts()
# Out:
# Country
# United States Of America    10014
# Australia                    2842
# France                       2830
# Mexico                       2651
# Germany                      2069
#                             ...
# Eritrea                         2
# Burundi                         2
# Chad                            2
# Bahrain                         2
# South Sudan                     2
# Name: count, Length: 147, dtype: int64

# %%
df[df['Country'] == 'Unknown']
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Country, Postal Code, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %%
df[df['Country'].isna()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Country, Postal Code, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['Country'] = df['Country'].str.lstrip().str.rstrip().str.title()

# %%
for x in df['Country'].drop_duplicates():
    print(x)
# Out:
# United States Of America
# Panama
# United Kingdom
# Nigeria
# Indonesia
# India
# Germany
# China
# Cuba
# Colombia
# Mexico
# Australia
# Brazil
# El Salvador
# Democratic Republic Of The Congo
# Argentina
# Honduras
# Denmark
# Pakistan
# Philippines
# Spain
# Zambia
# Bolivia
# Haiti
# Belgium
# New Zealand
# Nicaragua
# Libya
# France
# Morocco
# Mozambique
# Sweden
# Iran
# Albania
# Thailand
# Russia
# South Africa
# Egypt
# Austria
# Switzerland
# Ireland
# South Korea
# Vietnam
# Italy
# Kyrgyzstan
# Turkey
# Tanzania
# Algeria
# Dominican Republic
# Romania
# Cote D'Ivoire
# Malaysia
# Czech Republic
# Poland
# Canada
# Japan
# Sierra Leone
# Georgia
# Bangladesh
# Guatemala
# Zimbabwe
# Madagascar
# Venezuela
# Chile
# Belarus
# Cambodia
# Netherlands
# Benin
# Paraguay
# Guinea
# Senegal
# Ukraine
# Kenya
# Iraq
# Peru
# Saudi Arabia
# Norway
# Great Britain
# Singapore
# Djibouti
# Togo
# Kazakhstan
# Yemen
# Mali
# Hungary
# Sudan
# Finland
# Lithuania
# Hong Kong
# ...

# %%
df['Country'] = df['Country'].replace(
    {
        'U.S.A.':'United States Of America',
        'U.K.':'United Kingdom',
        'Usa':'United States Of America',
        'Uk':'United Kingdom',
        'Swaziland':'Switzerland',
        'United States':'United States Of America',
    }
)

# %%
df['Country'] = df['Country'].replace('Us','United States Of America')

# %%
df['Country'].isna().sum()
# Out:
# np.int64(0)

# %%
df.to_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v11.csv',index=False)
