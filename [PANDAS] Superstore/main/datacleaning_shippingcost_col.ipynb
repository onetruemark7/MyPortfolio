# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v18.csv')
df
# Out:
#        Row ID         Order ID  Order Date     Ship Date       Ship Mode  \
# 0       31518   CA-2012-169397  2012-12-24    27-12-2012     First Class
# 1        6224   US-2011-144729  2011-07-21    24-07-2011     First Class
# 2       15333  IT-2014-4749412  2014-09-18    23-09-2014  Standard Class
# 3       49259     NI-2013-4420  2013-04-10    10/10/2013  Standard Class
# 4       24199    IN-2014-14423  2014-10-29    30-10-2014     First Class
# ...       ...              ...         ...           ...             ...
# 51365   17526  ES-2014-2057259  2014-08-02      5/8/2014     First Class
# 51366   36055   CA-2011-121573  2011-11-03  Jul 11, 2011  Standard Class
# 51367   43576     TU-2011-9190  2011-12-23    28-12-2011    Second Class
# 51368   22403    IN-2013-35388  2013-08-07     11/8/2013  Standard Class
# 51369   12513  ES-2011-1222857  2011-09-30    2011-04-10  Standard Class
#
#       Customer ID     Customer Name    Segment            City  \
# ...

# %%
df['Shipping Cost'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Shipping Cost
# Non-Null Count  Dtype
# --------------  -----
# 50649 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['Shipping Cost'].value_counts()
# Out:
# Shipping Cost
# ?          124
# Unknown     91
# -           88
# 0.86        75
# 1.26        71
#           ...
# 20.98        1
# 141.27       1
# $13.28       1
# 169.01       1
# 64.42        1
# Name: count, Length: 11120, dtype: int64

# %%
df['Shipping Cost'].str.contains(r'[^0-9]',regex=True)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 51365     True
# 51366     True
# 51367     True
# 51368     True
# 51369     True
# Name: Shipping Cost, Length: 51370, dtype: bool

# %%
df[df['Shipping Cost'].str.contains(r'[^0-9.]',regex=True)]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Country, Postal Code, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['Shipping Cost'] = df['Shipping Cost'].str.replace(r'nan','')

# %%
df['Shipping Cost'] = pd.to_numeric(df['Shipping Cost'], errors='coerce')

# %%
df['Shipping Cost'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Shipping Cost'] = df['Shipping Cost'].fillna(0)

# %%
df['Shipping Cost'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Shipping Cost
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  float64
# dtypes: float64(1)
# memory usage: 401.5 KB

# %%
df.to_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v19.csv',index=False)
