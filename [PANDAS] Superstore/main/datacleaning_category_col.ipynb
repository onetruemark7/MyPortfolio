# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v12.csv')
df
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       31518   CA-2012-169397  2012-12-24  2012-12-27     First Class
# 1        6224   US-2011-144729  2011-07-21  2011-07-24     First Class
# 2       15333  IT-2014-4749412  2014-09-18  2014-09-23  Standard Class
# 3       49259     NI-2013-4420  2013-04-10  2013-10-10  Standard Class
# 4       24199    IN-2014-14423  2014-10-29  2014-10-30     First Class
# ...       ...              ...         ...         ...             ...
# 51365   17526  ES-2014-2057259  2014-08-02  2014-08-05     First Class
# 51366   36055   CA-2011-121573  2011-11-03  2011-07-11  Standard Class
# 51367   43576     TU-2011-9190  2011-12-23  2011-12-28    Second Class
# 51368   22403    IN-2013-35388  2013-08-07  2013-08-11  Standard Class
# 51369   12513  ES-2011-1222857  2011-09-30  2011-10-04  Standard Class
#
#       Customer ID     Customer Name    Segment            City  \
# ...

# %%
df['Market'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Market
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['Market'].value_counts()
# Out:
# Market
# APAC      11021
# LATAM     10315
# US        10014
# EU        10012
# EMEA       5031
# Africa     4593
# Canada      384
# Name: count, dtype: int64

# %%
df['Market'] = df['Market'].str.lstrip().str.rstrip()

# %%
df['Market'].isna().sum()
# Out:
# np.int64(0)

# %%
for x in df['Market'].drop_duplicates():
    print(x)
# Out:
# US
# LATAM
# EU
# Africa
# APAC
# EMEA
# Canada

# %%
df['Region'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Region
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['Region'].value_counts()
# Out:
# Region
# Central           11140
# South              6655
# EMEA               5031
# North              4793
# Africa             4593
# Oceania            3493
# West               3210
# Southeast Asia     3135
# East               2850
# North Asia         2339
# Central Asia       2054
# Caribbean          1693
# Canada              384
# Name: count, dtype: int64

# %%
df['Region'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Region'] = df['Region'].str.lstrip().str.rstrip()

# %%
df['Product ID'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Product ID
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['Product ID'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Product ID'].head()
# Out:
# 0     OFF-BI-10002852
# 1     OFF-FA-10002247
# 2     OFF-AR-10003113
# 3    OFF-AVE-10004512
# 4     FUR-FU-10002362
# Name: Product ID, dtype: str

# %%
df['Product ID'] = df['Product ID'].str.lstrip().str.rstrip()

# %%
df['Product ID'].str.contains(r'[^A-Z0-9-]',regex=True)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51365    False
# 51366    False
# 51367    False
# 51368    False
# 51369    False
# Name: Product ID, Length: 51370, dtype: bool

# %%
df['Category'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Category
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['Category'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    31316
# Technology         10162
# Furnitures          9892
# Name: count, dtype: int64

# %%
df['Category'] = df['Category'].str.lstrip().str.rstrip().str.title()

# %%
df['Category'] = df['Category'].replace(
    {
        'Office Suplies':'Office Supplies',
        'Ofice Supplies':'Office Supplies',
        'Office  Supplies':'Office Supplies',

        'Tecnology':'Technology',
        'Technolgy':'Technology',
        'Techonlogy':'Technology',

        'Furniture':'Furnitures',
        'Furnture':'Furnitures'
    }
)

# %%
df.to_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v13.csv',index=False)
