# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v8.csv')
df
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       31518   CA-2012-169397  2012-12-24  2012-12-27     First Class
# 1        6224   US-2011-144729  2011-07-21  2011-07-24     First Class
# 2       15333  IT-2014-4749412  2014-09-18  2014-09-23  Standard Class
# 3       49259     NI-2013-4420  2013-04-10  2013-10-10  Standard Class
# 4       24199    IN-2014-14423  2014-10-29  2014-10-30     First Class
# ...       ...              ...         ...         ...             ...
# 51365   17526  ES-2014-2057259  2014-08-02  2014-08-05     First Class
# 51366   36055   CA-2011-121573  2011-11-03  2011-07-11  Standard Class
# 51367   43576     TU-2011-9190  2011-12-23  2011-12-28    Second Class
# 51368   22403    IN-2013-35388  2013-08-07  2013-08-11  Standard Class
# 51369   12513  ES-2011-1222857  2011-09-30  2011-10-04  Standard Class
#
#       Customer ID     Customer Name    Segment            City  \
# ...

# %%
df['City'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: City
# Non-Null Count  Dtype
# --------------  -----
# 50728 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['City'].drop_duplicates()
# Out:
# 0                 Dublin
# 1          San Miguelito
# 2             Birmingham
# 3                  Lagos
# 4                Kendari
#               ...
# 50633    Charlottesville
# 50668             Passau
# 50901            Sagunto
# 51218      Saint-Laurent
# 51316            Zaoyang
# Name: City, Length: 3636, dtype: str

# %%
df['City'] = df['City'].str.lstrip().str.rstrip().str.title()

# %%
df['City'].value_counts()
# Out:
# City
# New York City      900
# Los Angeles        731
# Philadelphia       526
# San Francisco      496
# Santo Domingo      435
#                   ...
# Charlottesville      1
# Passau               1
# Sagunto              1
# Saint-Laurent        1
# Zaoyang              1
# Name: count, Length: 3635, dtype: int64

# %%
df['City'].str.contains(r'[0-9]')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51365    False
# 51366    False
# 51367    False
# 51368    False
# 51369    False
# Name: City, Length: 51370, dtype: bool

# %%
df[df['City'].str.contains(r'[0-9]')]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Country, Postal Code, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['City'].isna().sum()
# Out:
# np.int64(0)

# %%
df.loc[df['City'] == 'Unknown']
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 67      51051     IR-2011-1690  2011-07-29  2011-08-03  Standard Class
# 291     34837   CA-2011-158771  2011-05-09  2011-05-09        Same Day
# 301     32262   CA-2014-135279  2014-04-10  2014-04-12     First Class
# 371     43048     CA-2011-3390  2011-09-21  2011-09-24    Second Class
# 469     15034  ES-2012-4920028  2012-12-04  2012-10-12  Standard Class
# ...       ...              ...         ...         ...             ...
# 50893   18744  ES-2012-3446562  2012-11-24  2012-11-29  Standard Class
# 50937   28447    IN-2014-14850  2014-12-26  2014-12-31  Standard Class
# 51239   42405     TU-2013-7880  2013-09-19  2013-09-23  Standard Class
# 51267   17830  ES-2014-3014144  2014-04-06  2014-04-08     First Class
# 51336   23488    ID-2014-35521  2014-06-16  2014-06-18    Second Class
#
#       Customer ID     Customer Name      Segment     City  \
# ...

# %%
df['City'] = df['City'].fillna('Unknown')

# %%
df.to_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v9.csv',index=False)
