# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\source\superstore_dirty.csv')
df
# Out:
#         Row ID         Order ID    Order Date     Ship Date       Ship Mode  \
# 0      31518.0   CA-2012-169397    24-12-2012    27-12-2012     First Class
# 1       6224.0   US-2011-144729    21-07-2011    24-07-2011     First Class
# 2      15333.0  IT-2014-4749412    18-09-2014    23-09-2014  Standard Class
# 3      49259.0     NI-2013-4420  Apr 10, 2013    10/10/2013  Standard Class
# 4      24199.0    IN-2014-14423    29-10-2014    30-10-2014     First Class
# ...        ...              ...           ...           ...             ...
# 51520  17526.0  ES-2014-2057259      2/8/2014      5/8/2014     First Class
# 51521  36055.0   CA-2011-121573     3/11/2011  Jul 11, 2011  Standard Class
# 51522  43576.0     TU-2011-9190    23-12-2011    28-12-2011    Second Class
# 51523  22403.0    IN-2013-35388      7/8/2013     11/8/2013  Standard Class
# 51524  12513.0  ES-2011-1222857    30-09-2011    2011-04-10  Standard Class
#
# ...

# %%
df.shape
# Out:
# (51525, 24)

# %%
for cols in df.columns:
    print("df['"+cols+"']")
# Out:
# df['Row ID']
# df['Order ID']
# df['Order Date']
# df['Ship Date']
# df['Ship Mode']
# df['Customer ID']
# df['Customer Name']
# df['Segment']
# df['City']
# df['State']
# df['Country']
# df['Postal Code']
# df['Market']
# df['Region']
# df['Product ID']
# df['Category']
# df['Sub-Category']
# df['Product Name']
# df['Sales']
# df['Quantity']
# df['Discount']
# df['Profit']
# df['Shipping Cost']
# df['Order Priority']

# %%
df['Row ID']
# Out:
# 0        31518.0
# 1         6224.0
# 2        15333.0
# 3        49259.0
# 4        24199.0
#           ...
# 51520    17526.0
# 51521    36055.0
# 51522    43576.0
# 51523    22403.0
# 51524    12513.0
# Name: Row ID, Length: 51525, dtype: float64

# %%
df['Row ID'].drop_duplicates()
# Out:
# 0        31518.0
# 1         6224.0
# 2        15333.0
# 3        49259.0
# 4        24199.0
#           ...
# 51520    17526.0
# 51521    36055.0
# 51522    43576.0
# 51523    22403.0
# 51524    12513.0
# Name: Row ID, Length: 51251, dtype: float64

# %%
#df.loc[df['Row ID'].drop_duplicates(),'Row ID']
df['Row ID'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Row ID'] = df['Row ID'].fillna(df['Row ID'].ffill())

# %%
df.drop_duplicates()
# Out:
#         Row ID         Order ID    Order Date     Ship Date       Ship Mode  \
# 0      31518.0   CA-2012-169397    24-12-2012    27-12-2012     First Class
# 1       6224.0   US-2011-144729    21-07-2011    24-07-2011     First Class
# 2      15333.0  IT-2014-4749412    18-09-2014    23-09-2014  Standard Class
# 3      49259.0     NI-2013-4420  Apr 10, 2013    10/10/2013  Standard Class
# 4      24199.0    IN-2014-14423    29-10-2014    30-10-2014     First Class
# ...        ...              ...           ...           ...             ...
# 51520  17526.0  ES-2014-2057259      2/8/2014      5/8/2014     First Class
# 51521  36055.0   CA-2011-121573     3/11/2011  Jul 11, 2011  Standard Class
# 51522  43576.0     TU-2011-9190    23-12-2011    28-12-2011    Second Class
# 51523  22403.0    IN-2013-35388      7/8/2013     11/8/2013  Standard Class
# 51524  12513.0  ES-2011-1222857    30-09-2011    2011-04-10  Standard Class
#
# ...

# %%
df = df[~df.duplicated()]

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Country, Postal Code, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 51375 entries, 0 to 51524
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51375 non-null  int64
#  1   Order ID        51370 non-null  str
#  2   Order Date      51370 non-null  str
#  3   Ship Date       51370 non-null  str
#  4   Ship Mode       50667 non-null  str
#  5   Customer ID     51370 non-null  str
#  6   Customer Name   50387 non-null  str
#  7   Segment         50675 non-null  str
#  8   City            50728 non-null  str
#  9   State           50383 non-null  str
#  10  Country         51370 non-null  str
#  11  Postal Code     10143 non-null  float64
#  12  Market          51370 non-null  str
#  13  Region          51370 non-null  str
#  14  Product ID      51370 non-null  str
#  15  Category        51370 non-null  str
#  16  Sub-Category    50849 non-null  str
#  17  Product Name    51370 non-null  str
# ...

# %%
df['Row ID'].dtype
# Out:
# dtype('float64')

# %%
df['Row ID'].astype(int)
# Out:
# 0        31518
# 1         6224
# 2        15333
# 3        49259
# 4        24199
#          ...
# 51520    17526
# 51521    36055
# 51522    43576
# 51523    22403
# 51524    12513
# Name: Row ID, Length: 51375, dtype: int64

# %%
df['Row ID'] = df['Row ID'].astype(int)

# %%
df['Row ID'].dtype
# Out:
# dtype('int64')

# %%
df.to_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v1.csv', index=False)
