# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v17.csv')
df
# Out:
#        Row ID         Order ID  Order Date     Ship Date       Ship Mode  \
# 0       31518   CA-2012-169397  2012-12-24    27-12-2012     First Class
# 1        6224   US-2011-144729  2011-07-21    24-07-2011     First Class
# 2       15333  IT-2014-4749412  2014-09-18    23-09-2014  Standard Class
# 3       49259     NI-2013-4420  2013-04-10    10/10/2013  Standard Class
# 4       24199    IN-2014-14423  2014-10-29    30-10-2014     First Class
# ...       ...              ...         ...           ...             ...
# 51365   17526  ES-2014-2057259  2014-08-02      5/8/2014     First Class
# 51366   36055   CA-2011-121573  2011-11-03  Jul 11, 2011  Standard Class
# 51367   43576     TU-2011-9190  2011-12-23    28-12-2011    Second Class
# 51368   22403    IN-2013-35388  2013-08-07     11/8/2013  Standard Class
# 51369   12513  ES-2011-1222857  2011-09-30    2011-04-10  Standard Class
#
#       Customer ID     Customer Name    Segment            City  \
# ...

# %%
df['Profit'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Profit
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['Profit'].value_counts()
# Out:
# Profit
#  0.00      674
#  4.32       74
#  7.92       72
#  2.88       72
#  3.96       72
#           ...
#  56.27       1
# -42.05       1
# -12.83       1
#  205.08      1
# -182.03      1
# Name: count, Length: 16568, dtype: int64

# %%
df['Profit'].str.contains(r'[^0-9.-]',regex=True)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51365    False
# 51366    False
# 51367    False
# 51368    False
# 51369    False
# Name: Profit, Length: 51370, dtype: bool

# %%
df[df['Profit'].str.contains(r'[^0-9.-]',regex=True)]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Country, Postal Code, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['Profit'] = df['Profit'].str.replace(r',','')

# %%
df['Profit'] = pd.to_numeric(df['Profit']).round(2)

# %%
df['Profit'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Profit'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Profit
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  float64
# dtypes: float64(1)
# memory usage: 401.5 KB

# %%
df.to_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v18.csv',index=False)
