# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_clean.csv')
df
# Out:
#        Row ID         Order ID  Order Date     Ship Date       Ship Mode  \
# 0       31518   CA-2012-169397  2012-12-24    27-12-2012     First Class
# 1        6224   US-2011-144729  2011-07-21    24-07-2011     First Class
# 2       15333  IT-2014-4749412  2014-09-18    23-09-2014  Standard Class
# 3       49259     NI-2013-4420  2013-04-10    10/10/2013  Standard Class
# 4       24199    IN-2014-14423  2014-10-29    30-10-2014     First Class
# ...       ...              ...         ...           ...             ...
# 51365   17526  ES-2014-2057259  2014-08-02      5/8/2014     First Class
# 51366   36055   CA-2011-121573  2011-11-03  Jul 11, 2011  Standard Class
# 51367   43576     TU-2011-9190  2011-12-23    28-12-2011    Second Class
# 51368   22403    IN-2013-35388  2013-08-07     11/8/2013  Standard Class
# 51369   12513  ES-2011-1222857  2011-09-30    2011-04-10  Standard Class
#
#       Customer ID     Customer Name    Segment            City  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51370 entries, 0 to 51369
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51370 non-null  int64
#  1   Order ID        51370 non-null  str
#  2   Order Date      51370 non-null  str
#  3   Ship Date       51370 non-null  str
#  4   Ship Mode       50667 non-null  str
#  5   Customer ID     51370 non-null  str
#  6   Customer Name   50387 non-null  str
#  7   Segment         50675 non-null  str
#  8   City            50728 non-null  str
#  9   State           50383 non-null  str
#  10  Country         51370 non-null  str
#  11  Postal Code     10143 non-null  float64
#  12  Market          51370 non-null  str
#  13  Region          51370 non-null  str
#  14  Product ID      51370 non-null  str
#  15  Category        51370 non-null  str
#  16  Sub-Category    51370 non-null  str
#  17  Product Name    51370 non-null  str
# ...

# %%
df['Discount'].value_counts()
# Out:
# Discount
# 0.00    29106
# 0.20     4970
# 0.10     3989
# 0.40     3226
# 0.60     1987
# 0.70     1745
# 0.50     1598
# 0.17      727
# 0.47      715
# 0.15      534
# 0.27      380
# 0.30      335
# 0.45      320
# 0.80      315
# 0.25      196
# 0.07      149
# 0.35      121
# 0.37       69
# 0.32       27
# 0.65       17
# 0.57       12
# 0.55       10
# 0.85        2
# Name: count, dtype: int64

# %%
df['Discount'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Discount'] = df['Discount'].fillna(df['Discount'].median())

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51370 entries, 0 to 51369
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51370 non-null  int64
#  1   Order ID        51370 non-null  str
#  2   Order Date      51370 non-null  str
#  3   Ship Date       51370 non-null  str
#  4   Ship Mode       51370 non-null  str
#  5   Customer ID     51370 non-null  str
#  6   Customer Name   50387 non-null  str
#  7   Segment         50675 non-null  str
#  8   City            50728 non-null  str
#  9   State           50383 non-null  str
#  10  Country         51370 non-null  str
#  11  Postal Code     10143 non-null  float64
#  12  Market          51370 non-null  str
#  13  Region          51370 non-null  str
#  14  Product ID      51370 non-null  str
#  15  Category        51370 non-null  str
#  16  Sub-Category    51370 non-null  str
#  17  Product Name    51370 non-null  str
# ...

# %%
df['Ship Mode'].isna().sum()
# Out:
# np.int64(703)

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    30218
# Second Class      10109
# First Class        7377
# Same Day           2640
# Unknown             323
# Name: count, dtype: int64

# %%
df['Ship Mode'] = df['Ship Mode'].str.lstrip().str.rstrip().str.title()

# %%
df['Ship Mode'] = df['Ship Mode'].replace(
    {
        '-':'Unknown',
        '?':'Unknown',
        'None':'Unknown',
        'Nan':'Unknown',
    }
)

# %%
df['Ship Mode'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Ship Mode'] = df['Ship Mode'].fillna('Unknown')

# %%
df['Customer Name'].isna().sum()
# Out:
# np.int64(983)

# %%
df['Customer Name'].drop_duplicates()
# Out:
# 0    Unknown
# Name: Customer Name, dtype: str

# %%
df['Customer Name'] = 'Unknown'

# %%
df['Customer Name'] = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_clean.csv', usecols=['Customer Name'])

# %%
df['Customer Name'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Customer Name
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['Customer Name']
# Out:
# 0          Joni Blumstein
# 1        Saphhira Shifley
# 2              Mick Brown
# 3           Michael Paige
# 4             Daniel Lacy
#                ...
# 51365        Philip Brown
# 51366    Speros Goranitis
# 51367      Cari Macintyre
# 51368                 NaN
# 51369       Darren Powers
# Name: Customer Name, Length: 51370, dtype: str

# %%
df['Customer Name'] = df['Customer Name'].str.lstrip().str.rstrip().str.title()

# %%
df['Customer Name'] == 'Unknown'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51365    False
# 51366    False
# 51367    False
# 51368    False
# 51369    False
# Name: Customer Name, Length: 51370, dtype: bool

# %%
df[df['Customer Name'] == 'Nan']
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Country, Postal Code, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['Customer Name'].isna().sum()
# Out:
# np.int64(983)

# %%
df['Customer Name'] = df['Customer Name'].fillna('Unknown')

# %%
df['Customer Name'] = df['Customer Name'].replace('Nan','Unknown')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51370 entries, 0 to 51369
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51370 non-null  int64
#  1   Order ID        51370 non-null  str
#  2   Order Date      51370 non-null  str
#  3   Ship Date       51370 non-null  str
#  4   Ship Mode       51370 non-null  str
#  5   Customer ID     51370 non-null  str
#  6   Customer Name   51370 non-null  str
#  7   Segment         51370 non-null  str
#  8   City            50728 non-null  str
#  9   State           50383 non-null  str
#  10  Country         51370 non-null  str
#  11  Postal Code     10143 non-null  float64
#  12  Market          51370 non-null  str
#  13  Region          51370 non-null  str
#  14  Product ID      51370 non-null  str
#  15  Category        51370 non-null  str
#  16  Sub-Category    51370 non-null  str
#  17  Product Name    51370 non-null  str
# ...

# %%
df['Segment'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: Segment
# Non-Null Count  Dtype
# --------------  -----
# 50675 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['Customer Name'].value_counts()
# Out:
# Customer Name
# Unknown            1505
# Muhammed Yedwab     103
# Steven Ward         101
# Bill Eplett         101
# Gary Hwang           99
#                    ...
# Brendan Dodson       32
# Andy Reiter          32
# Nicole Brennan       29
# Michael Oakman       29
# Darren Budd          28
# Name: count, Length: 797, dtype: int64

# %%
df['Customer Name'] = df['Customer Name'].str.lstrip().str.rstrip().str.title()

# %%
df['Customer Name'] = df['Customer Name'].replace('?','Unknown')
df['Customer Name'] = df['Customer Name'].replace('-','Unknown')
df['Customer Name'] = df['Customer Name'].replace('Null','Unknown')
df['Customer Name'] = df['Customer Name'].replace('None','Unknown')

# %%
df['Segment'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Segment'].drop_duplicates()
# Out:
# 0       Consumer
# 1      Corporate
# 2        Unknown
# 9    Home Office
# Name: Segment, dtype: str

# %%
df['Segment'] = df['Segment'].str.lstrip().str.rstrip().str.title()

# %%
df['Segment'] = df['Segment'].replace(
    {
        '-':'Unknown',
        '?':'Unknown',
        'None':'Unknown',
        'Nan':'Unknown',
    }
)

# %%
df['Segment'] = df['Segment'].fillna('Unknown')

# %%
df['City'].value_counts()
# Out:
# City
# New York City      900
# Unknown            791
# Los Angeles        731
# Philadelphia       526
# San Francisco      496
#                   ...
# Charlottesville      1
# Passau               1
# Sagunto              1
# Saint-Laurent        1
# Zaoyang              1
# Name: count, Length: 3632, dtype: int64

# %%
df['City'] = df['City'].str.lstrip().str.rstrip().str.title()

# %%
df[df['City'] == 'NaN']
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Country, Postal Code, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['City'] = df['City'].replace('Nan','Unknown')

# %%
df['City'].isna().sum()
# Out:
# np.int64(0)

# %%
df['City'] = df['City'].fillna('Unknown')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 51370 entries, 0 to 51369
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          51370 non-null  int64
#  1   Order ID        51370 non-null  str
#  2   Order Date      51370 non-null  str
#  3   Ship Date       51370 non-null  str
#  4   Ship Mode       51370 non-null  str
#  5   Customer ID     51370 non-null  str
#  6   Customer Name   51370 non-null  str
#  7   Segment         51370 non-null  str
#  8   City            51370 non-null  str
#  9   State           51370 non-null  str
#  10  Country         51370 non-null  str
#  11  Postal Code     51370 non-null  int64
#  12  Market          51370 non-null  str
#  13  Region          51370 non-null  str
#  14  Product ID      51370 non-null  str
#  15  Category        51370 non-null  str
#  16  Sub-Category    51370 non-null  str
#  17  Product Name    51370 non-null  str
# ...

# %%
df['State'] = df['State'].str.lstrip().str.rstrip().str.title()

# %%
df[df['State'] == 'Nan']
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Country, Postal Code, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['State'] = df['State'].replace('Nan','Unknown')

# %%
df['State'].isna().sum()
# Out:
# np.int64(0)

# %%
df['State'] = df['State'].fillna('Unknown')

# %%
df['Postal Code'].value_counts()
# Out:
# Postal Code
# 0        41483
# 10035      261
# 10009      226
# 10024      225
# 94122      203
#          ...
# 38134        1
# 8302         1
# 84041        1
# 32935        1
# 27534        1
# Name: count, Length: 632, dtype: int64

# %%
df['Postal Code'].isna().sum()
# Out:
# np.int64(41227)

# %%
df['Postal Code'] = df['Postal Code'].fillna(0)

# %%
df['Postal Code'] = df['Postal Code'].astype(int)

# %%
df.to_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_clean.csv',index=False)
