# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v9.csv')
df
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       31518   CA-2012-169397  2012-12-24  2012-12-27     First Class
# 1        6224   US-2011-144729  2011-07-21  2011-07-24     First Class
# 2       15333  IT-2014-4749412  2014-09-18  2014-09-23  Standard Class
# 3       49259     NI-2013-4420  2013-04-10  2013-10-10  Standard Class
# 4       24199    IN-2014-14423  2014-10-29  2014-10-30     First Class
# ...       ...              ...         ...         ...             ...
# 51365   17526  ES-2014-2057259  2014-08-02  2014-08-05     First Class
# 51366   36055   CA-2011-121573  2011-11-03  2011-07-11  Standard Class
# 51367   43576     TU-2011-9190  2011-12-23  2011-12-28    Second Class
# 51368   22403    IN-2013-35388  2013-08-07  2013-08-11  Standard Class
# 51369   12513  ES-2011-1222857  2011-09-30  2011-10-04  Standard Class
#
#       Customer ID     Customer Name    Segment            City  \
# ...

# %%
df['State'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: State
# Non-Null Count  Dtype
# --------------  -----
# 50383 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['State'] = df['State'].str.lstrip().str.rstrip().str.title()

# %%
df['State'].value_counts()
# Out:
# State
# California       1952
# England          1466
# New York         1094
# Texas             960
# Ile-De-France     957
#                  ...
# Ibb                 1
# Novgorod            1
# La Rioja            1
# Savanes             1
# Yevrey              1
# Name: count, Length: 1099, dtype: int64

# %%
df['State'].drop_duplicates()
# Out:
# 0                     Ohio
# 1                   Panama
# 2                  England
# 3                    Lagos
# 4        Sulawesi Tenggara
#                ...
# 46857                  Ibb
# 47796             Novgorod
# 48100             La Rioja
# 48290              Savanes
# 50263               Yevrey
# Name: State, Length: 1100, dtype: str

# %%
df['State'].str.contains(r'[0-9]').sum()
# Out:
# np.int64(0)

# %%
df['State'].isna().sum()
# Out:
# np.int64(0)

# %%
df[df['State'] == 'Unknown' ]
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 31      29547    ID-2014-35073  2014-04-09  2014-04-12     First Class
# 175     14873  IT-2014-2277753  2014-01-14  2014-01-16    Second Class
# 188     15487  ES-2012-1158066  2012-09-08  2012-09-10    Second Class
# 191     42631     TU-2013-3960  2013-06-22  2013-06-26    Second Class
# 223      2923   MX-2014-151218  2014-04-16  2014-04-18     First Class
# ...       ...              ...         ...         ...             ...
# 50998   36753   CA-2014-130631  2014-12-30  2015-01-03  Standard Class
# 51014    6698   MX-2014-144722  2014-06-06  2014-11-06  Standard Class
# 51020    5402   MX-2011-149027  2011-10-22  2011-10-27  Standard Class
# 51217   42807     AJ-2012-7720  2012-11-02  2012-11-05     First Class
# 51285    1105   US-2012-142699  2012-01-28  2012-02-04  Standard Class
#
#       Customer ID      Customer Name      Segment             City    State  \
# ...

# %%
df['State'] = df['State'].fillna('Unknown')

# %%
df['State'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51370 entries, 0 to 51369
# Series name: State
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df.to_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v10.csv',index=False)
