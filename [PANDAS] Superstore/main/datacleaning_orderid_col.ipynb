# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v1.csv')
df
# Out:
#        Row ID         Order ID    Order Date     Ship Date       Ship Mode  \
# 0       31518   CA-2012-169397    24-12-2012    27-12-2012     First Class
# 1        6224   US-2011-144729    21-07-2011    24-07-2011     First Class
# 2       15333  IT-2014-4749412    18-09-2014    23-09-2014  Standard Class
# 3       49259     NI-2013-4420  Apr 10, 2013    10/10/2013  Standard Class
# 4       24199    IN-2014-14423    29-10-2014    30-10-2014     First Class
# ...       ...              ...           ...           ...             ...
# 51370   17526  ES-2014-2057259      2/8/2014      5/8/2014     First Class
# 51371   36055   CA-2011-121573     3/11/2011  Jul 11, 2011  Standard Class
# 51372   43576     TU-2011-9190    23-12-2011    28-12-2011    Second Class
# 51373   22403    IN-2013-35388      7/8/2013     11/8/2013  Standard Class
# 51374   12513  ES-2011-1222857    30-09-2011    2011-04-10  Standard Class
#
#       Customer ID     Customer Name    Segment            City  \
# ...

# %%
df['Order ID'].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 51375 entries, 0 to 51374
# Series name: Order ID
# Non-Null Count  Dtype
# --------------  -----
# 51370 non-null  str
# dtypes: str(1)
# memory usage: 401.5 KB

# %%
df['Order ID'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51370     True
# 51371     True
# 51372     True
# 51373     True
# 51374     True
# Name: Order ID, Length: 51375, dtype: bool

# %%
df['Order ID'] = df['Order ID'].str.strip()

# %%
df['Order ID'].str.contains("")
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 51370    True
# 51371    True
# 51372    True
# 51373    True
# 51374    True
# Name: Order ID, Length: 51375, dtype: bool

# %%
df[df['Order ID'].isna()]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Country, Postal Code, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %%
df['Order ID'].isna().drop(columns='Order ID', inplace=True)

# %%
df.loc[df['Order ID'].isna(),'Order ID']
# Out:
# 4837     NaN
# 12652    NaN
# 21844    NaN
# 23071    NaN
# 38711    NaN
# Name: Order ID, dtype: str

# %%
df.loc[df['Order ID'].isna(),'Order ID'].drop(columns='Order ID', inplace=True)

# %%
df['Order ID'].dropna(inplace=True)

# %%
df[df['Order ID'].notna()]
# Out:
#        Row ID         Order ID    Order Date     Ship Date       Ship Mode  \
# 0       31518   CA-2012-169397    24-12-2012    27-12-2012     First Class
# 1        6224   US-2011-144729    21-07-2011    24-07-2011     First Class
# 2       15333  IT-2014-4749412    18-09-2014    23-09-2014  Standard Class
# 3       49259     NI-2013-4420  Apr 10, 2013    10/10/2013  Standard Class
# 4       24199    IN-2014-14423    29-10-2014    30-10-2014     First Class
# ...       ...              ...           ...           ...             ...
# 51370   17526  ES-2014-2057259      2/8/2014      5/8/2014     First Class
# 51371   36055   CA-2011-121573     3/11/2011  Jul 11, 2011  Standard Class
# 51372   43576     TU-2011-9190    23-12-2011    28-12-2011    Second Class
# 51373   22403    IN-2013-35388      7/8/2013     11/8/2013  Standard Class
# 51374   12513  ES-2011-1222857    30-09-2011    2011-04-10  Standard Class
#
#       Customer ID     Customer Name    Segment            City  \
# ...

# %%
df = df[df['Order ID'].notna()]

# %%
df['Order ID'].str.contains(r"[^A-Za-z0-9-]",regex=True)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51370    False
# 51371    False
# 51372    False
# 51373    False
# 51374    False
# Name: Order ID, Length: 51370, dtype: bool

# %%
df['Order ID']
# Out:
# 0         CA-2012-169397
# 1         US-2011-144729
# 2        IT-2014-4749412
# 3           NI-2013-4420
# 4          IN-2014-14423
#               ...
# 51370    ES-2014-2057259
# 51371     CA-2011-121573
# 51372       TU-2011-9190
# 51373      IN-2013-35388
# 51374    ES-2011-1222857
# Name: Order ID, Length: 51370, dtype: str

# %%
df[df['Order ID'].str.contains(r"[^A-Za-z0-9-]",regex=True)]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order ID, Order Date, Ship Date, Ship Mode, Customer ID, Customer Name, Segment, City, State, Country, Postal Code, Market, Region, Product ID, Category, Sub-Category, Product Name, Sales, Quantity, Discount, Profit, Shipping Cost, Order Priority]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.to_csv(r'C:\Users\Marcus\Desktop\python pandas\superstore_data\version_control\superstore_v2.csv',index=False)
